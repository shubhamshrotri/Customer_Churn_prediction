# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Importing dataset

# %%
df=pd.read_csv('Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %% [markdown]
# ## Converting categorical variables to dummy variables

# %%
Gender_1=pd.get_dummies(df['gender'],drop_first=True)

# %%
partner=pd.get_dummies(df['Partner'],drop_first=True)

# %%
partner =partner.rename(columns={'Yes': 'partner'})

# %%
dependents=pd.get_dummies(df['Dependents'], drop_first=True)

# %%
dependents= dependents.rename(columns={'Yes': 'dependents'})

# %%
phoneservice=pd.get_dummies(df['PhoneService'], drop_first=True)

# %%
phoneservice = phoneservice.rename(columns={'Yes': 'phoneservice'})

# %%
MultipleLines=pd.get_dummies(df['MultipleLines'], drop_first=True)

# %%
MultipleLines = MultipleLines.rename(columns={'Yes': 'MultipleLines'})

# %%
internetservice = pd.get_dummies(df['InternetService'], drop_first = True)

# %%
internetservice = internetservice.rename( columns={'No': 'No internet service'})

# %%
onlinesecurity = pd.get_dummies(df['OnlineSecurity'], drop_first = True)

# %%
onlinesecurity = onlinesecurity.rename( columns={'Yes': 'onlinesecurity'})

# %%
onlinebackup = pd.get_dummies(df['OnlineBackup'], drop_first = True)

# %%
onlinebackup = onlinebackup.rename(columns={'Yes': 'onlinebackup'})

# %%
deviceprotection = pd.get_dummies(df['DeviceProtection'], drop_first = True)

# %%
deviceprotection = deviceprotection.rename( columns={'Yes': 'deviceprotection'})

# %%
techsupport = pd.get_dummies(df['TechSupport'], drop_first = True)

# %%
techsupport = techsupport.rename( columns={'Yes': 'techsupport'})

# %%
streamingtv = pd.get_dummies(df['StreamingTV'], drop_first = True)

# %%
streamingtv = streamingtv.rename( columns={'Yes': 'streamingtv'})

# %%
streamingmovies = pd.get_dummies(df['StreamingMovies'], drop_first = True)

# %%
streamingmovies = streamingmovies.rename( columns={'Yes': 'streamingmovies'})

# %%
contract = pd.get_dummies(df['Contract'], drop_first = True)

# %%
paperlessbilling = pd.get_dummies(df['PaperlessBilling'], drop_first = True)

# %%
paperlessbilling = paperlessbilling.rename( columns = {'Yes': 'paperlessbilling'})

# %%
paymentmethod = pd.get_dummies(df['PaymentMethod'], drop_first = True)

# %%
churn_1 = pd.get_dummies(df['Churn'], drop_first = True)

# %%
churn_1 = churn_1.rename( columns = {'Yes': 'churn'})

# %% [markdown]
# ## Concatening Dataframes

# %%
df5 = pd.concat([df,Gender_1,partner,dependents,phoneservice,MultipleLines,internetservice,
                 onlinesecurity,onlinebackup,deviceprotection,techsupport,streamingtv,streamingmovies,
                 contract,paperlessbilling, churn_1], axis =1)

# %%
df5
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
df5 = df5.drop(['gender','Partner','Churn','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup',
          'DeviceProtection', 'TechSupport','StreamingTV','StreamingMovies', 'Contract','PaperlessBilling','PaymentMethod']
        ,axis =1)

# %%
df5.columns
# Out:
# Index(['customerID', 'SeniorCitizen', 'tenure', 'MonthlyCharges',
#        'TotalCharges', 'Male', 'partner', 'dependents', 'phoneservice',
#        'No phone service', 'Fiber optic', 'No internet service',
#        'No internet service', 'onlinesecurity', 'No internet service',
#        'onlinebackup', 'No internet service', 'deviceprotection',
#        'No internet service', 'techsupport', 'No internet service',
#        'streamingtv', 'No internet service', 'streamingmovies', 'One year',
#        'Two year', 'paperlessbilling', 'churn'],
#       dtype='object')

# %%
df5.head()
# Out:
#    customerID  SeniorCitizen  tenure  MonthlyCharges TotalCharges  Male  \
# 0  7590-VHVEG              0       1           29.85        29.85     0
# 1  5575-GNVDE              0      34           56.95       1889.5     1
# 2  3668-QPYBK              0       2           53.85       108.15     1
# 3  7795-CFOCW              0      45           42.30      1840.75     1
# 4  9237-HQITU              0       2           70.70       151.65     0
#
#    partner  dependents  phoneservice  No phone service  ...    \
# 0        1           0             0                 1  ...
# 1        0           0             1                 0  ...
# 2        0           0             1                 0  ...
# 3        0           0             0                 1  ...
# 4        0           0             1                 0  ...
#
#    No internet service  techsupport  No internet service  streamingtv  \
# 0                    0            0                    0            0
# ...

# %% [markdown]
# ## Cleaning Dataframe

# %%
df7 = pd.DataFrame(df5[['TotalCharges','tenure','MonthlyCharges']])

# %%
df5=df5.drop(['MonthlyCharges','TotalCharges'],axis=1)

# %%
a = []
for i in df7['TotalCharges'].values[0:]:
    try:
        a.append(float(i))
    except ValueError:
        a.append(i)

# %%
j = 0
for i in a:
    if type(i) == str:
        a[j] =0
        print(type(a[j]))
    j+=1
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
type(a)
# Out:
# list

# %%
df7['TotalCharges'].values[0:] = a

# %%
df7['TotalCharges'] = df7['TotalCharges'].astype(float)

# %%
df7['TotalCharges'].replace([0],[np.nan],inplace=True)

# %%
def impute_TC(cols):
    print(cols[0:3])
    TotalCharges = cols[0]
    tenure = cols[1]
    MonthlyCharges = cols[2]
    
    if pd.isnull(TotalCharges):
        return (tenure*MonthlyCharges)
    else:
        return(TotalCharges)

# %%
df7['TotalCharges'] = df7[['TotalCharges','tenure','MonthlyCharges']].apply(impute_TC,axis=1)
# Out:
# TotalCharges      29.85
# tenure             1.00
# MonthlyCharges    29.85
# Name: 0, dtype: float64
# TotalCharges      1889.50
# tenure              34.00
# MonthlyCharges      56.95
# Name: 1, dtype: float64
# TotalCharges      108.15
# tenure              2.00
# MonthlyCharges     53.85
# Name: 2, dtype: float64
# TotalCharges      1840.75
# tenure              45.00
# MonthlyCharges      42.30
# Name: 3, dtype: float64
# TotalCharges      151.65
# tenure              2.00
# MonthlyCharges     70.70
# Name: 4, dtype: float64
# TotalCharges      820.50
# tenure              8.00
# MonthlyCharges     99.65
# Name: 5, dtype: float64
# TotalCharges      1949.4
# tenure              22.0
# MonthlyCharges      89.1
# Name: 6, dtype: float64
# TotalCharges      301.90
# tenure             10.00
# MonthlyCharges     29.75
# Name: 7, dtype: float64
# TotalCharges      3046.05
# tenure              28.00
# MonthlyCharges     104.80
# Name: 8, dtype: float64
# TotalCharges      3487.95
# ...

# %%
df7= df7.drop(['tenure','MonthlyCharges'], axis=1)

# %%
df5 = pd.concat([df5, df7], axis =1)

# %%
df5.head()
# Out:
#    customerID  SeniorCitizen  tenure  Male  partner  dependents  phoneservice  \
# 0  7590-VHVEG              0       1     0        1           0             0
# 1  5575-GNVDE              0      34     1        0           0             1
# 2  3668-QPYBK              0       2     1        0           0             1
# 3  7795-CFOCW              0      45     1        0           0             0
# 4  9237-HQITU              0       2     0        0           0             1
#
#    No phone service  Fiber optic  No internet service      ...       \
# 0                 1            0                    0      ...
# 1                 0            0                    0      ...
# 2                 0            0                    0      ...
# 3                 1            0                    0      ...
# 4                 0            1                    0      ...
#
#    techsupport  No internet service  streamingtv  No internet service  \
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 27 columns):
# customerID             7043 non-null object
# SeniorCitizen          7043 non-null int64
# tenure                 7043 non-null int64
# Male                   7043 non-null uint8
# partner                7043 non-null uint8
# dependents             7043 non-null uint8
# phoneservice           7043 non-null uint8
# No phone service       7043 non-null uint8
# Fiber optic            7043 non-null uint8
# No internet service    7043 non-null uint8
# No internet service    7043 non-null uint8
# onlinesecurity         7043 non-null uint8
# No internet service    7043 non-null uint8
# onlinebackup           7043 non-null uint8
# No internet service    7043 non-null uint8
# deviceprotection       7043 non-null uint8
# No internet service    7043 non-null uint8
# techsupport            7043 non-null uint8
# No internet service    7043 non-null uint8
# ...

# %%
df5= df5.drop(['customerID'], axis =1)

# %%
df5 =df5.T.drop_duplicates().T

# %%
df5.columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'Male', 'partner', 'dependents',
#        'phoneservice', 'No phone service', 'Fiber optic',
#        'No internet service', 'onlinesecurity', 'onlinebackup',
#        'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies',
#        'One year', 'Two year', 'paperlessbilling', 'churn', 'TotalCharges'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.heatmap(df5.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.set_style('whitegrid')
sns.countplot(x='churn',data=df5,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='churn',hue='Male',data=df5,palette='rainbow')

# %%
sns.factorplot(x="SeniorCitizen", hue="Male", col="churn",
               data=df5, kind="count",
               size=4, aspect=.7);

# %%
sns.boxplot(x="techsupport", y="TotalCharges", hue="churn",
            data=df5)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
# SeniorCitizen          7043 non-null float64
# tenure                 7043 non-null float64
# Male                   7043 non-null float64
# partner                7043 non-null float64
# dependents             7043 non-null float64
# phoneservice           7043 non-null float64
# No phone service       7043 non-null float64
# Fiber optic            7043 non-null float64
# No internet service    7043 non-null float64
# onlinesecurity         7043 non-null float64
# onlinebackup           7043 non-null float64
# deviceprotection       7043 non-null float64
# techsupport            7043 non-null float64
# streamingtv            7043 non-null float64
# streamingmovies        7043 non-null float64
# One year               7043 non-null float64
# Two year               7043 non-null float64
# paperlessbilling       7043 non-null float64
# ...

# %%
churn2 = churn_1['churn']

# %%
df5= df5.drop(['churn'],axis = 1)

# %% [markdown]
# ## Performing Logistic regression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df5, 
                                                    churn2, test_size=0.25, 
                                                    random_state=100)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.82      0.89      0.86      1272
#           1       0.64      0.50      0.56       489
#
# avg / total       0.77      0.78      0.77      1761

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[1132,  140],
#        [ 243,  246]], dtype=int64)

# %% [markdown]
# ## Model is predicting customer would churn or not with 78%

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 6)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=6, p=2,
#            weights='uniform')

# %%
y_pred = knn.predict(X_test)

# %%
from sklearn import metrics

# %%
print (metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.758091993186

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1179,   93],
#        [ 333,  156]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.78      0.93      0.85      1272
#           1       0.63      0.32      0.42       489
#
# avg / total       0.74      0.76      0.73      1761

# %% [markdown]
# ## Model is predicting customer would churn or not with 76%

# %%
from xgboost.sklearn import XGBClassifier

# %%
xclas = XGBClassifier()

# %%
xclas.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
y_pred = xclas.predict(X_test)

# %%
accuracy = metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.78080636002271442

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1134,  138],
#        [ 248,  241]], dtype=int64)

# %%
import xgboost as xgb

# %%
train = pd.concat([df5,churn_1],axis=1)

# %%
target = 'churn'

# %%
def modelfit(alg, dtrain, predictors,useTrainCV=True, cv_folds=5, early_stopping_rounds=50):
    
    if useTrainCV:
        xgb_param = alg.get_xgb_params()
        xgtrain = xgb.DMatrix(dtrain[predictors].values, label=dtrain[target].values)
        cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds,
            metrics='auc', early_stopping_rounds=early_stopping_rounds)
        alg.set_params(n_estimators=cvresult.shape[0])
    
    #Fit the algorithm on the data
    alg.fit(dtrain[predictors], dtrain['churn'],eval_metric='auc')
        
    #Predict training set:
    dtrain_predictions = alg.predict(dtrain[predictors])
    dtrain_predprob = alg.predict_proba(dtrain[predictors])[:,1]
        
    #Print model report:
    print ("\nModel Report")
    print ("Accuracy : %.4g" % metrics.accuracy_score(dtrain['churn'].values, dtrain_predictions))
    print ("AUC Score (Train): %f" % metrics.roc_auc_score(dtrain['churn'], dtrain_predprob))

# %%
predictors = [x for x in train.columns if x not in [target]]
xgb1 = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=5,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
modelfit(xgb1, train, predictors)
# Out:
# Model Report
# Accuracy : 0.8106
# AUC Score (Train): 0.866506

# %%
from sklearn.grid_search import GridSearchCV
# Out:
# F:\MS\education\python\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# F:\MS\education\python\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
param_test1 = {
 'max_depth': np.arange(3,10,2),
 'min_child_weight': np.arange(1,6,2)
}
gsearch1 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=140, max_depth=5,
 min_child_weight=1, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27), 
 param_grid = param_test1, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch1.fit(train[predictors],train[target])
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# ([mean: 0.84558, std: 0.01154, params: {'max_depth': 3, 'min_child_weight': 1},
#   mean: 0.84456, std: 0.01088, params: {'max_depth': 3, 'min_child_weight': 3},
#   mean: 0.84510, std: 0.01147, params: {'max_depth': 3, 'min_child_weight': 5},
#   mean: 0.83768, std: 0.01327, params: {'max_depth': 5, 'min_child_weight': 1},
#   mean: 0.83786, std: 0.01213, params: {'max_depth': 5, 'min_child_weight': 3},
#   mean: 0.83836, std: 0.01227, params: {'max_depth': 5, 'min_child_weight': 5},
#   mean: 0.82791, std: 0.01262, params: {'max_depth': 7, 'min_child_weight': 1},
#   mean: 0.82909, std: 0.01236, params: {'max_depth': 7, 'min_child_weight': 3},
#   mean: 0.83092, std: 0.01115, params: {'max_depth': 7, 'min_child_weight': 5},
#   mean: 0.82047, std: 0.01395, params: {'max_depth': 9, 'min_child_weight': 1},
#   mean: 0.82237, std: 0.01193, params: {'max_depth': 9, 'min_child_weight': 3},
#   mean: 0.82578, std: 0.01156, params: {'max_depth': 9, 'min_child_weight': 5}],
# ...

# %%
param_test2 = {
 'max_depth':[2,3,4],
 'min_child_weight':[0,1,2]
}
gsearch2 = GridSearchCV(estimator = XGBClassifier( learning_rate=0.1, n_estimators=140, max_depth=5,
 min_child_weight=2, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test2, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch2.fit(train[predictors],train[target])
gsearch2.grid_scores_, gsearch2.best_params_, gsearch2.best_score_
# Out:
# ([mean: 0.84665, std: 0.01069, params: {'max_depth': 2, 'min_child_weight': 0},
#   mean: 0.84650, std: 0.01046, params: {'max_depth': 2, 'min_child_weight': 1},
#   mean: 0.84659, std: 0.01061, params: {'max_depth': 2, 'min_child_weight': 2},
#   mean: 0.84484, std: 0.01168, params: {'max_depth': 3, 'min_child_weight': 0},
#   mean: 0.84558, std: 0.01154, params: {'max_depth': 3, 'min_child_weight': 1},
#   mean: 0.84510, std: 0.01099, params: {'max_depth': 3, 'min_child_weight': 2},
#   mean: 0.84096, std: 0.01085, params: {'max_depth': 4, 'min_child_weight': 0},
#   mean: 0.84150, std: 0.01265, params: {'max_depth': 4, 'min_child_weight': 1},
#   mean: 0.84181, std: 0.01147, params: {'max_depth': 4, 'min_child_weight': 2}],
#  {'max_depth': 2, 'min_child_weight': 0},
#  0.8466451414986542)

# %%
param_test3 = {
 'gamma':[i/10.0 for i in range(0,5)]
}
gsearch3 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=140, max_depth=4,
 min_child_weight=6, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test3, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch3.fit(train[predictors],train[target])
gsearch3.grid_scores_, gsearch3.best_params_, gsearch3.best_score_
# Out:
# ([mean: 0.84234, std: 0.01084, params: {'gamma': 0.0},
#   mean: 0.84216, std: 0.01163, params: {'gamma': 0.1},
#   mean: 0.84266, std: 0.01162, params: {'gamma': 0.2},
#   mean: 0.84256, std: 0.01185, params: {'gamma': 0.3},
#   mean: 0.84211, std: 0.01162, params: {'gamma': 0.4}],
#  {'gamma': 0.2},
#  0.8426596368974)

# %%
predictors = [x for x in train.columns if x not in [target]]
xgb1 = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=2,
 min_child_weight=0,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
modelfit(xgb1, train, predictors)
# Out:
# Model Report
# Accuracy : 0.8046
# AUC Score (Train): 0.854974

# %%
param_test4 = {
 'subsample':[i/10.0 for i in range(6,10)],
 'colsample_bytree':[i/10.0 for i in range(6,10)]
}
gsearch4 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=177, max_depth=2,
 min_child_weight=0, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test4, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch4.fit(train[predictors],train[target])
gsearch4.grid_scores_, gsearch4.best_params_, gsearch4.best_score_
# Out:
# ([mean: 0.84699, std: 0.01160, params: {'colsample_bytree': 0.6, 'subsample': 0.6},
#   mean: 0.84698, std: 0.01174, params: {'colsample_bytree': 0.6, 'subsample': 0.7},
#   mean: 0.84692, std: 0.01215, params: {'colsample_bytree': 0.6, 'subsample': 0.8},
#   mean: 0.84649, std: 0.01113, params: {'colsample_bytree': 0.6, 'subsample': 0.9},
#   mean: 0.84673, std: 0.01160, params: {'colsample_bytree': 0.7, 'subsample': 0.6},
#   mean: 0.84666, std: 0.01144, params: {'colsample_bytree': 0.7, 'subsample': 0.7},
#   mean: 0.84647, std: 0.01111, params: {'colsample_bytree': 0.7, 'subsample': 0.8},
#   mean: 0.84646, std: 0.01108, params: {'colsample_bytree': 0.7, 'subsample': 0.9},
#   mean: 0.84659, std: 0.01148, params: {'colsample_bytree': 0.8, 'subsample': 0.6},
#   mean: 0.84652, std: 0.01099, params: {'colsample_bytree': 0.8, 'subsample': 0.7},
#   mean: 0.84653, std: 0.01122, params: {'colsample_bytree': 0.8, 'subsample': 0.8},
# ...

# %%
param_test5 = {
 'subsample':[i/100.0 for i in range(55,70,5)],
 'colsample_bytree':[i/100.0 for i in range(55,70,5)]
}
gsearch5 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=177, max_depth=2,
 min_child_weight=0, gamma=0, subsample=0.6, colsample_bytree=0.6,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test5, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch5.fit(train[predictors],train[target])
gsearch5.grid_scores_, gsearch5.best_params_, gsearch5.best_score_
# Out:
# ([mean: 0.84691, std: 0.01196, params: {'colsample_bytree': 0.55, 'subsample': 0.55},
#   mean: 0.84663, std: 0.01188, params: {'colsample_bytree': 0.55, 'subsample': 0.6},
#   mean: 0.84664, std: 0.01191, params: {'colsample_bytree': 0.55, 'subsample': 0.65},
#   mean: 0.84669, std: 0.01203, params: {'colsample_bytree': 0.6, 'subsample': 0.55},
#   mean: 0.84699, std: 0.01160, params: {'colsample_bytree': 0.6, 'subsample': 0.6},
#   mean: 0.84654, std: 0.01157, params: {'colsample_bytree': 0.6, 'subsample': 0.65},
#   mean: 0.84673, std: 0.01171, params: {'colsample_bytree': 0.65, 'subsample': 0.55},
#   mean: 0.84656, std: 0.01168, params: {'colsample_bytree': 0.65, 'subsample': 0.6},
#   mean: 0.84639, std: 0.01160, params: {'colsample_bytree': 0.65, 'subsample': 0.65}],
#  {'colsample_bytree': 0.6, 'subsample': 0.6},
#  0.8469894447773983)

# %%
param_test6 = {
 'reg_alpha':[1e-5, 1e-2, 0.1, 1, 100]
}
gsearch6 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=177, max_depth=2,
 min_child_weight=0, gamma=0.1, subsample=0.6, colsample_bytree=0.6,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test6, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch6.fit(train[predictors],train[target])
gsearch6.grid_scores_, gsearch6.best_params_, gsearch6.best_score_
# Out:
# ([mean: 0.84696, std: 0.01190, params: {'reg_alpha': 1e-05},
#   mean: 0.84677, std: 0.01179, params: {'reg_alpha': 0.01},
#   mean: 0.84701, std: 0.01201, params: {'reg_alpha': 0.1},
#   mean: 0.84731, std: 0.01153, params: {'reg_alpha': 1},
#   mean: 0.82452, std: 0.00881, params: {'reg_alpha': 100}],
#  {'reg_alpha': 1},
#  0.8473059003082397)

# %%
param_test7 = {
 'reg_alpha':[0, 0.01, 0.5, 1, 5]
}
gsearch7 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=177, max_depth=2,
 min_child_weight=0, gamma=0, subsample=0.6, colsample_bytree=0.6,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test7, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch7.fit(train[predictors],train[target])
gsearch7.grid_scores_, gsearch7.best_params_, gsearch7.best_score_
# Out:
# ([mean: 0.84699, std: 0.01160, params: {'reg_alpha': 0},
#   mean: 0.84696, std: 0.01150, params: {'reg_alpha': 0.01},
#   mean: 0.84673, std: 0.01154, params: {'reg_alpha': 0.5},
#   mean: 0.84733, std: 0.01158, params: {'reg_alpha': 1},
#   mean: 0.84784, std: 0.01144, params: {'reg_alpha': 5}],
#  {'reg_alpha': 5},
#  0.8478421520903986)

# %%
param_test7 = {
 'reg_alpha':[0, 0.05, 5, 5, 25]
}
gsearch7 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=177, max_depth=2,
 min_child_weight=0, gamma=0, subsample=0.6, colsample_bytree=0.6,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test7, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch7.fit(train[predictors],train[target])
gsearch7.grid_scores_, gsearch7.best_params_, gsearch7.best_score_
# Out:
# ([mean: 0.84699, std: 0.01160, params: {'reg_alpha': 0},
#   mean: 0.84686, std: 0.01183, params: {'reg_alpha': 0.05},
#   mean: 0.84784, std: 0.01144, params: {'reg_alpha': 5},
#   mean: 0.84784, std: 0.01144, params: {'reg_alpha': 5},
#   mean: 0.84528, std: 0.01036, params: {'reg_alpha': 25}],
#  {'reg_alpha': 5},
#  0.8478421520903986)

# %%
xgb3 = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=2,
 min_child_weight=0,
 gamma=0,
 subsample=0.6,
 colsample_bytree=0.6,
 reg_alpha=5,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
modelfit(xgb3, train, predictors)
# Out:
# Model Report
# Accuracy : 0.8065
# AUC Score (Train): 0.855219

# %%
xgb4 = XGBClassifier(
 learning_rate =0.01,
 n_estimators=5000,
 max_depth=2,
 min_child_weight=0,
 gamma=0,
 subsample=0.6,
 colsample_bytree=0.6,
 reg_alpha=5,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
modelfit(xgb4, train, predictors)
# Out:
# Model Report
# Accuracy : 0.8078
# AUC Score (Train): 0.853874

# %%
y_pred = xgb4.predict(X_test)

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.79840999432140825

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1153,  119],
#        [ 236,  253]], dtype=int64)

# %%
from sklearn.svm import SVC

# %%
svm = SVC()

# %%
svm.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred = svm.predict(X_test)

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.75865985235661559

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1180,   92],
#        [ 333,  156]], dtype=int64)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None)

# %%
y_pred = gnb.predict(X_test)

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.72118114707552528

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[897, 375],
#        [116, 373]], dtype=int64)
